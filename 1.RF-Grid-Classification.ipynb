# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.24.3

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]} 


grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1') 
   
# fitting the model for grid search 
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.83869734 0.86573742 0.83049656 0.86160787
#         nan        nan 0.83074065 0.85548101 0.82829623 0.85062271]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              scoring='f1', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)


# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001547      0.000898         0.000000        0.000000
# 1        0.001188      0.000382         0.000000        0.000000
# 2        0.039181      0.001183         0.009333        0.000811
# 3        0.351361      0.007226         0.030562        0.000724
# 4        0.037582      0.001276         0.008751        0.000942
# 5        0.355567      0.008714         0.031552        0.002623
# 6        0.000713      0.000411         0.000000        0.000000
# 7        0.000972      0.000272         0.000000        0.000000
# 8        0.038418      0.002385         0.008129        0.000381
# 9        0.367184      0.010463         0.029600        0.001377
# 10       0.041057      0.006982         0.008178        0.000399
# 11       0.338714      0.053331         0.026275        0.003339
#
#    param_criterion param_max_features param_n_estimators  \
# 0             gini               auto                 10
# 1             gini               auto                100
# 2             gini               sqrt                 10
# 3             gini               sqrt                100
# 4             gini               log2                 10
# 5             gini               log2                100
# 6          entropy               auto                 10
# 7          entropy               auto                100
# 8          entropy               sqrt                 10
# 9          entropy               sqrt                100
# 10         entropy               log2                 10
# 11         entropy               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 1   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.800000
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.800000
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           0.727273
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.833333
# 6   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 7   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...           0.800000
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.800000
# 10  {'criterion': 'entropy', 'max_features': 'log2...           0.764706
# 11  {'criterion': 'entropy', 'max_features': 'log2...           0.800000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.842105           0.790698           0.871795
# 3            0.871795           0.809524           0.900000
# 4            0.833333           0.809524           0.900000
# 5            0.842105           0.809524           0.900000
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.842105           0.809524           0.837209
# 9            0.820513           0.809524           0.900000
# 10           0.777778           0.809524           0.842105
# 11           0.820513           0.809524           0.900000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1                 NaN              NaN             NaN                9
# 2            0.888889         0.838697        0.038543                5
# 3            0.947368         0.865737        0.055418                1
# 4            0.882353         0.830497        0.061029                7
# 5            0.923077         0.861608        0.042767                2
# 6                 NaN              NaN             NaN                9
# 7                 NaN              NaN             NaN                9
# 8            0.864865         0.830741        0.023369                6
# 9            0.947368         0.855481        0.058031                3
# 10           0.947368         0.828296        0.065295                8
# 11           0.923077         0.850623        0.050688                4

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}: 0.918082172961622

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[79  6]
#  [ 5 44]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        85
#            1       0.88      0.90      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.91      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
table_pr=pd.DataFrame()

# %%
print(X_test)
# Out:
#      Age  EstimatedSalary  Gender_Male
# 132   30            87000            1
# 309   38            50000            0
# 341   35            75000            1
# 196   30            79000            0
# 246   35            50000            0
# ..   ...              ...          ...
# 168   29           148000            1
# 150   26            15000            0
# 393   60            42000            1
# 66    24            19000            1
# 240   42           149000            1
#
# [134 rows x 3 columns]

# %%
table_pr['Age']=X_test["Age"]
table_pr['Gender_male']=X_test["Gender_Male"]
table_pr['Estimated_Salary']=X_test["EstimatedSalary"]
table_pr['Actual']=y_test
table_pr['Predicted']=grid_predictions

# %%
table_pr.head(134)
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 132   30            1             87000       0          0
# 309   38            0             50000       0          0
# 341   35            1             75000       0          0
# 196   30            0             79000       0          0
# 246   35            0             50000       0          0
# ..   ...          ...               ...     ...        ...
# 168   29            1            148000       1          1
# 150   26            0             15000       0          0
# 393   60            1             42000       1          1
# 66    24            1             19000       0          0
# 240   42            1            149000       1          1
#
# [134 rows x 5 columns]
